# %%
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
import pmdarima as pm

# %%
forecast_period = 20

# %%
data = pd.read_csv('./sales_train.csv', parse_dates=['Date'], index_col='Date')

# %%
data = data[['Price']]
data = data.sort_values(by=['Date']).groupby(['Date']).mean().round(2)

# %%
data['Price'] = data.Price.replace('[\,]', '', regex=True).astype(float)
actual = data.plot(label='Actual sale', figsize=(19, 4))
actual.set_xlabel('Date')
actual.set_ylabel('Sales')
plt.legend()
plt.show()

# %%
smodel = pm.auto_arima(data, start_p=1, start_q=1, max_p=3, max_q=3, m=7,start_P=0, seasonal=True,d=1, D=1, trace=True,
                                 error_action='ignore',  
                                 suppress_warnings=True, 
                                 stepwise=True)
print(smodel.summary().tables[1])
smodel.plot_diagnostics(figsize=(18, 8))
plt.show()
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=3657.816, BIC=3676.751, Fit time=2.464 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 7); AIC=3879.597, BIC=3887.170, Fit time=0.047 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 7); AIC=3802.100, BIC=3817.247, Fit time=0.608 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 7); AIC=3702.117, BIC=3717.265, Fit time=0.751 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=3656.082, BIC=3678.803, Fit time=2.707 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 0, 7); AIC=3748.267, BIC=3767.202, Fit time=0.820 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 7); AIC=3661.700, BIC=3688.209, Fit time=4.272 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 7); AIC=3814.028, BIC=3829.175, Fit time=0.578 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 2, 7); AIC=3659.983, BIC=3690.278, Fit time=4.875 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=3700.988, BIC=3719.923, Fit time=0.968 seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(1, 1, 1, 7); AIC=3657.492, BIC=3684.000, Fit time=2.111 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 1, 7); AIC=3709.609, BIC=3728.543, Fit time=0.963 seconds
# Fit ARIMA: order=(1, 1, 2) seasonal_order=(1, 1, 1, 7); AIC=3657.209, BIC=3683.717, Fit time=3.053 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 1, 1, 7); AIC=3716.795, BIC=3731.943, Fit time=0.775 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(1, 1, 1, 7); AIC=3658.873, BIC=3689.168, Fit time=3.498 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(2, 1, 1, 7); AIC=3657.212, BIC=3683.720, Fit time=5.555 seconds
# Total fit time: 34.065 seconds
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0154      0.007      2.148      0.032       0.001       0.029
# ar.L1          0.5964      0.039     15.165      0.000       0.519       0.674
# ma.L1         -0.9993      0.352     -2.841      0.005      -1.689      -0.310
# ar.S.L7        0.1098      0.060      1.835      0.066      -0.007       0.227
# ma.S.L7       -0.9988      1.479     -0.675      0.499      -3.897       1.899
# sigma2      3772.3774   5357.970      0.704      0.481   -6729.050    1.43e+04
# ==============================================================================

# %%
 # Forecast
n_periods = forecast_period
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
fitted = fitted.round(2)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='D')

predicted = pd.DataFrame()
predicted['Date'] = index_of_fc
predicted['Amount'] = fitted
predicted = predicted.set_index('Date')

frames = [data, predicted]
result = pd.concat(frames)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   del sys.path[0]

# %%
x = np.arange(data.shape[0] + predicted.shape[0])
fig ,ax = plt.subplots(1, 1, figsize=(20, 5))
ax.plot(result.index[x[:data.shape[0]]], data, alpha=0.75, c='blue', label='Actual')
ax.plot(result.index[x[data.shape[0]:]], predicted, alpha=0.75, c='red',  label='Forcast')  # Forecasts
ax.fill_between(result.index[x[-predicted.shape[0]:]],
                 confint[:, 0], confint[:, 1],
                 alpha=0.1, color='g')
ax.set_title("Forecasts")
ax.set_xlabel("Date")
plt.show()
